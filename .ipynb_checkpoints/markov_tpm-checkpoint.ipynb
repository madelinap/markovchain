# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Build the Transition Matrix of Probabilities is given
# ### - on rows we have old states
# ### - on columns we have new state

# %%
edges = pd.read_csv(f'edges.20211117_v3.csv',
                    low_memory=False, 
                    encoding='utf-8',
                    float_precision='round_trip')

# %%
edges.shape
# Out:
# (10015, 9)

# %%
edges.head()
# Out:
#    HRTB Id Event Effective Date  seq_id  \
# 0      423           2007-07-10     1.0
# 1      423           2008-06-02     2.0
# 2      423           2008-12-19     3.0
# 3      423           2011-02-08     4.0
# 4      464           2010-09-27     1.0
#
#                                     position_from                position_to  \
# 0                       game designer(artistique)              game designer
# 1                                   game designer          camera specialist
# 2                               camera specialist              game designer
# 3                                   game designer             audio designer
# 4  network administrator(services professionnels)  senior applications admin
#
#    upd      position_from_upd            position_to_upd  transition_days
# 0    1          game designer              game designer                0
# 1    0          game designer          camera specialist                0
# 2    0      camera specialist              game designer                0
# 3    0          game designer             audio designer                0
# 4    1  network administrator  senior applications admin                0

# %%
edges_agg = edges.groupby(['position_from_upd','position_to_upd'])['HRTB Id'].count().to_frame().reset_index()

# %%
edges_agg
# Out:
#                 position_from_upd  \
# 0                   2d compositor
# 1                   2d compositor
# 2                   2d compositor
# 3                   2d compositor
# 4                   2d compositor
# ...                           ...
# 3651                    webmestre
# 3652               world director
# 3653     worldwide music director
# 3654                     wrangler
# 3655  ww quality control director
#
#                                   position_to_upd  HRTB Id
# 0                                   2d compositor        5
# 1                                    2d-3d artist        1
# 2                                graphic designer        1
# 3                          production coordinator        1
# 4                   project manager ( qc)(design)        1
# ...                                           ...      ...
# 3651                    conseiller - com internes        1
# 3652                            creative director        1
# 3653  svp, music special advisor to the president        1
# 3654                                  3d animator        1
# 3655                      quality control manager        1
#
# [3656 rows x 3 columns]

# %%
allstates = set(edges_agg['position_from_upd']).union(set(edges_agg['position_to_upd']))
n = len(allstates)
print("n=",n)
# Out:
# n= 1256

# %%
# for i,source in enumerate(allstates):
#     print(i,source)

# %%
# tmp = [[0 for i in range(n)] for j in range(n)]

# %%
# tmp[0][0]
# Out:
# 0

# %%
tmp = [[0 for i in range(n)] for j in range(n)]
for i,source in enumerate(allstates):
    for j,dest in enumerate(allstates):
        df = edges_agg[(edges_agg['position_from_upd'] == source) & (edges_agg['position_to_upd'] == dest)]['HRTB Id']
        if df.shape[0] != 0:
            tmp[i][j] = df.iloc[0]

# %%
p = [[0 for i in range(n)] for j in range(n)]
for i in range(n):
    i_sum = 0
    for j in range(n):
        i_sum = i_sum + tmp[i][j]
    if i_sum > 0:
        for j in range(n):
            p[i][j] = tmp[i][j]/i_sum
    else:
        p[i][i] = 1

# %%
# The statespace
# states = ["Developer","TeamLead","Assistant","Director"]
states = list(allstates)

# %%
if sum(p[0])+sum(p[1])+sum(p[2]) != 3:
    print("Somewhere, something went wrong. Transition matrix, perhaps?")
else: print("All is gonna be okay, you should move on!! ;)")
# Out:
# All is gonna be okay, you should move on!! ;)

# %% [markdown]
# ## Build the graph with:
# ### 1 - vertex = states
# ### 2- edges weight = -log(p(i,j)

# %%
import networkx as nx  # For the magic
import matplotlib.pyplot as plt  # For plotting

# %%
G = nx.MultiDiGraph()
labels={}
edge_labels={}

for i, origin_state in enumerate(states):
    for j, destination_state in enumerate(states):
        rate = -np.log(0.01+p[i][j])
        if rate > 0:
            G.add_edge(origin_state,
                       destination_state,
                       weight=rate,
                       label="{:.02f}".format(rate))
            edge_labels[(origin_state, destination_state)] = label="{:.02f}".format(rate)

# %%
# G.nodes()

# %%
# G.edges()

# %%
pos=nx.spring_layout(G)
pos
# Out:
# {'character modeler': array([-0.03034969, -0.20620903]),
#  'it coordinator(services professionnels)': array([-0.64583492, -0.4490031 ]),
#  'spécialist utilisabilité (que)(services professionnels)': array([-0.08115973, -0.2004962 ]),
#  'erg & partnership coordinator': array([ 0.27436176, -0.60543668]),
#  'tgo services  director': array([0.56576514, 0.49382001]),
#  'analyste controle de gestion': array([0.20310867, 0.74799132]),
#  'assistant artistic director - graphic': array([0.5026505 , 0.51197582]),
#  'payroll manager': array([-0.36739352,  0.62916696]),
#  'executive assistant - ceo': array([0.18376943, 0.75314707]),
#  'assistante administrative': array([-0.33305421,  0.73112267]),
#  'level design team lead': array([-0.26527518,  0.02389636]),
#  'virtualization administrator': array([ 0.59476882, -0.12989363]),
#  'project lead - game design': array([-0.37358734, -0.67150635]),
#  'project lead - game design(informatique)': array([ 0.06276168, -0.86013049]),
#  'analyste antipiratage': array([0.56763369, 0.14457886]),
#  'level designer': array([-0.01398972, -0.72811919]),
#  'helpdesk specialist': array([-0.58594173, -0.62226033]),
#  'technical instructor': array([-0.30025467,  0.75862807]),
#  'assistante coord recherche mkt': array([0.03092409, 0.76846552]),
#  'perf capt pipeline specialist': array([ 0.4197849 , -0.47952926]),
#  'helix project director': array([0.24743769, 0.72767627]),
#  'internal communications and brand content director': array([-0.0559035 , -0.20166229]),
#  "producteur - école d'été": array([0.5719313 , 0.46605858]),
#  'administrateur sécurité': array([ 0.31549352, -0.4462972 ]),
#  'dt prod pipeline (que)(artistique)': array([ 0.199164  , -0.34306812]),
#  'associate it director': array([-0.85918242,  0.11013917]),
#  'actionscript developer': array([0.19073142, 0.74574912]),
#  'project lead - level design(informatique)': array([0.46622467, 0.55858862]),
#  'project lead - animation(services professionnels)': array([ 0.479422  , -0.38081577]),
#  'it developer': array([-0.04830137, -0.19888718]),
#  'tester(dev test)': array([-0.02819397, -0.39353213]),
#  'assistant technical director - design(informatique)': array([-0.02587907, -0.20324707]),
#  'data analyst - it': array([ 0.67757213, -0.49406916]),
#  'paymaster(services support)': array([-0.62430191, -0.05077544]),
#  'assistant technical director - animation': array([-0.27189806, -0.06209731]),
#  'operations director': array([-0.40133494,  0.62997323]),
#  'manager, corporate affairs': array([-0.76450354,  0.14315324]),
#  'cinematic animator': array([-0.91754609,  0.08857155]),
#  'directeur online services': array([0.3652136 , 0.09735361]),
#  'animator - main character': array([-0.56649178, -0.01926311]),
#  'talent development director': array([-0.85975677,  0.13617741]),
#  'coordonateur - evenements': array([ 0.06512502, -0.18610163]),
#  'tester(tools automation)': array([ 0.18667603, -0.37315136]),
#  'video editor': array([ 0.03848124, -0.19473837]),
#  'capture artist': array([-0.90050793,  0.09537436]),
#  'tech lead release & build': array([-0.25988415,  0.03693105]),
#  'administrative assistant': array([0.35401973, 0.60101801]),
#  'localization project manager': array([-0.08624973, -0.1956311 ]),
#  'physical security project manager': array([-0.03661271, -0.20261386]),
#  'senior internal mobility advisor': array([0.06137412, 0.76704681]),
#  'team lead mocap': array([ 0.36220664, -0.11211496]),
#  'director of property management': array([-0.26330632,  0.01651569]),
#  'bi specialist': array([0.51619732, 0.54448128]),
#  'product manager(informatique)': array([ 0.25424051, -0.63927776]),
#  'chief accountant': array([-0.33115107,  0.69778335]),
#  'technicien de production(services support)': array([-0.04318715, -0.20124361]),
#  'sr legal counsel trademark&ip': array([-0.69706708, -0.49520063]),
#  'data protection officer': array([0.52058834, 0.52133578]),
#  'sound integrator(informatique)': array([0.15312563, 0.7515865 ]),
#  'tools developer(services professionnels)': array([-0.41397518,  0.62933999]),
#  'directeur groupe productivite': array([-0.3831203 , -0.65134704]),
#  'director - digital services': array([-0.9383871 ,  0.24441691]),
#  'senior executive vice president': array([-0.6367622 ,  0.47260189]),
#  'architecte de système': array([ 0.26094991, -0.74039263]),
#  'directeur it': array([-0.82627213,  0.22089426]),
#  'game keys specialist': array([-0.30636543, -0.11873785]),
#  'production project manager(services professionnels)': array([-0.44226602, -0.70931286]),
#  'dir narrative design': array([ 0.0168098 , -0.19616053]),
#  'ethical hacker(it corpo)': array([-0.36370492, -0.1575997 ]),
#  'music design specialist': array([-0.41470528,  0.63007355]),
#  'presentation director': array([0.04529443, 0.77021641]),
#  'marketing game manager(services support)': array([0.37013751, 0.61105609]),
#  'video editor(services professionnels)': array([ 0.19048229, -0.23143758]),
#  'outsourcing team lead': array([-0.0277649, -0.2018699]),
#  'associate managing director': array([ 0.6030457 , -0.61250943]),
#  'brand manager (que) - mkg': array([-0.75994986,  0.12826732]),
#  'dir intérim - rémun globale': array([-0.30472529, -0.77239633]),
#  'gest communauté pipeline (que)': array([ 0.27652094, -0.18959993]),
#  'video editor(services support)': array([0.5957619 , 0.00670247]),
#  'dir. métiers de production': array([-0.08596599, -0.19893909]),
#  'purchasing agent(services support)': array([-0.25998795, -0.05699693]),
#  'online technology director': array([-0.26301911, -0.02643963]),
#  'sound technician(services support)': array([ 0.10016332, -0.29086706]),
#  'production coordinator(design)': array([ 0.62396622, -0.58524972]),
#  'alice studio director': array([-0.75744814,  0.11857522]),
#  'analyst programmer (qc)': array([-0.02940505, -0.20554121]),
#  'strategic planning team lead': array([-0.3157565 ,  0.73236144]),
#  'historian(tools automation)': array([-0.03869577, -0.19865535]),
#  'google compliance specialist tester': array([0.42302713, 0.65399414]),
#  'producteur éxécutif': array([-0.88885736,  0.27169046]),
#  'pmo coordinator': array([-0.47029737, -0.13146111]),
#  'assistant director - level design': array([0.53637391, 0.50465399]),
#  'web designer(services professionnels)': array([ 0.00335988, -0.35006124]),
#  'assistant cinematic director': array([-0.28597775,  0.77415067]),
#  'executive director - hr & communications': array([0.57900053, 0.46586481]),
#  'world director': array([ 0.77207452, -0.05656441]),
#  'directeur formation': array([0.60596263, 0.43215868]),
#  'modeler': array([ 0.17248216, -0.14185566]),
#  'artistic manager - helix': array([-0.03114208, -0.19973148]),
#  'senior producer(producteurs)': array([-0.74646187,  0.49949133]),
#  'system and online operation specialist': array([-0.26212639, -0.04481692]),
#  'user research lab coordinator': array([0.43615872, 0.5927757 ]),
#  'dir efficacité organisation': array([ 0.19598059, -0.5537166 ]),
#  'operations manager': array([0.72139251, 0.09360965]),
#  'dir métier adjoint - gestion': array([0.62522233, 0.43445629]),
#  'director - digital services(gestion)': array([-0.01875792, -0.20264846]),
#  'internal community manager': array([-0.33685353,  0.66376585]),
#  'conseiller communications - rh': array([-0.29244146, -0.15797341]),
#  'svp, music special advisor to the president': array([-0.05781009,  0.76970428]),
#  'director - level design(autres)': array([ 0.02793791, -0.19432314]),
#  'production manager - helix(gestion)': array([-0.03118707, -0.20337857]),
#  'technicien post-production': array([-0.28640336,  0.74661762]),
#  'application and infrastructure security manager': array([-0.0747064 , -0.20134395]),
#  'game intelligence analyst(services professionnels)': array([ 0.21281807, -0.79378057]),
#  'organizational development advisor': array([-0.02711437, -0.41164643]),
#  'product specialist - design': array([-0.28816116,  0.7716766 ]),
#  '3d programmer(artistique)': array([-0.90117574, -0.09846089]),
#  'creative director': array([0.48526287, 0.54722869]),
#  'concept artist': array([-0.71894962,  0.00619727]),
#  'security specialist': array([-0.91939044,  0.06997626]),
#  'creative director - helix': array([-0.72441673,  0.0149655 ]),
#  'directeur administratif qc': array([-0.26209179,  0.03098291]),
#  'stagiaire(artistique)': array([0.6903162 , 0.17271399]),
#  'business strategy and live performance director': array([-0.06945723, -0.19896331]),
#  'game release manager': array([0.47278181, 0.60266507]),
#  'community developer': array([ 0.63688326, -0.47112781]),
#  'manager, business relationship': array([0.75481141, 0.00199309]),
#  'technical writer(tools automation)': array([-0.34018227, -0.75851387]),
#  'brand technology director': array([ 0.28261441, -0.18374521]),
#  'associate director': array([-0.34486052, -0.75803983]),
#  'directeur sécurité': array([-0.86259073,  0.18891479]),
#  'gns production services director': array([ 0.47660881, -0.50755024]),
#  'project lead - animation(gestion)': array([-0.54757124,  0.60374808]),
#  'system administrator - monitoring': array([0.65704608, 0.30583256]),
#  'coord mobilité internationale': array([ 0.04154354, -0.32662162]),
#  'technicien administration sirh': array([ 0.18898746, -0.50864708]),
#  'hq senior producer': array([-0.71860701, -0.46765029]),
#  'production director - alice': array([0.09516674, 0.76288068]),
#  'executive director - production services studio': array([-0.88096803,  0.09005599]),
#  'applications specialist': array([-0.39573976,  0.64325702]),
#  'texture artist': array([0.52471298, 0.48230091]),
#  'vp of production transformation': array([ 0.27230293, -0.1697555 ]),
#  'product manager - mkg': array([-0.03933591, -0.20163114]),
#  'wrangler': array([ 0.3315663, -0.6488176]),
#  'ai programmer': array([ 0.26790842, -0.16843715]),
#  'music licensing manager': array([ 0.37952858, -0.68186283]),
#  'internal communications manager': array([-0.26285648,  0.02188942]),
#  'online store manager': array([ 0.7737112 , -0.05956097]),
#  'chargé de communication': array([-0.34346259,  0.66921914]),
#  'chargé de projet - helix(services professionnels)': array([-0.30627546,  0.74957955]),
#  'film director (consultant)': array([0.70083183, 0.13359262]),
#  'tg director - tools & middleware': array([ 0.50615227, -0.66805303]),
#  'international mobility coordinator': array([-0.40659797,  0.63827085]),
#  'events communication specialist': array([-0.05788275, -0.20001176]),
#  'associate audio director': array([-0.38186768,  0.6325165 ]),
#  'coordonnateur production-video(gestion)': array([-0.29056948,  0.7681368 ]),
#  'customer service representative': array([ 0.03297947, -0.1937868 ]),
#  'vice president, human resources & communications': array([ 0.35596439, -0.6952678 ]),
#  'fun house executive director': array([-0.41211012,  0.63716704]),
#  'coord playtests(services support)': array([ 0.35309586, -0.64485914]),
#  'team lead service technique(services professionnels)': array([-0.32982233,  0.70614672]),
#  'team lead developpeur web': array([ 0.7387594, -0.218742 ]),
#  'lead technique localisation': array([ 0.18226077, -0.23757258]),
#  'prototypeur(informatique)': array([-0.41201323,  0.62627769]),
#  'project manager ( qc)(services professionnels)': array([0.63542998, 0.32497457]),
#  'cmk analyst': array([0.73411578, 0.0564433 ]),
#  'community management specialist': array([-0.63695252, -0.59092796]),
#  'modeler(informatique)': array([ 0.12002505, -0.85493326]),
#  'chargé de projet - helix(gestion)': array([-0.26826829, -0.70176262]),
#  'chargé de projet - ubik(services professionnels)': array([-0.26053122, -0.00438411]),
#  'coord - communications(services support)': array([-0.26283571,  0.0048028 ]),
#  'cmk manager': array([0.22887701, 0.74215388]),
#  'responsable service clientèle(it corpo)': array([-0.2594274 , -0.05736718]),
#  'communication coordinator(services support)': array([ 0.06292777, -0.32829639]),
#  'marketing game manager(autres)': array([-0.04683423, -0.20632668]),
#  'directeur exploitation cgi': array([-0.74563146,  0.19145806]),
#  'project security analyst team lead\xa0': array([ 0.09978962, -0.17653754]),
#  'associate producer': array([ 0.27500188, -0.19345117]),
#  'executive director marketing': array([ 6.92046306e-05, -1.98935628e-01]),
#  'assistant cinematic director(artistique)': array([-0.04469235, -0.85734153]),
#  'director - it services': array([-0.39313766, -0.69480062]),
#  'web designer(artistique)': array([0.69610858, 0.15211524]),
#  'project security manager': array([-0.05393463, -0.19799791]),
#  'artistic director - animation': array([0.73123688, 0.06968214]),
#  'logistics clerk(contrôle qualité)': array([0.56372017, 0.48691338]),
#  'technicien de production(gestion)': array([-0.05731874, -0.20241316]),
#  'hr specialist': array([-0.29517159,  0.76832366]),
#  'product manager - management': array([0.54486191, 0.45878172]),
#  'physical security analyst': array([0.72446519, 0.07315622]),
#  'directeur informatique': array([-0.05856788, -0.20273842]),
#  'sec monitor & incid respon mgr': array([-0.04915951, -0.20280762]),
#  'support team manager - ncsa': array([ 0.28892934, -0.60062701]),
#  'assitante coord recherche mkt': array([-0.03196562, -0.20482148]),
#  'responsable nouveau concept': array([-0.05870629,  0.76965237]),
#  'assistant director - alice studio': array([-0.06667866, -0.19453076]),
#  'human resources team lead': array([0.59221172, 0.4560689 ]),
#  'chargé de projet principal loc': array([-0.39433143,  0.63732272]),
#  'worldwide music director': array([-0.17522267,  0.72472471]),
#  'commis admin-communication': array([0.60041589, 0.46008623]),
#  'info & corporate security mgr(services professionnels)': array([-0.6343919 , -0.48592722]),
#  'executive assistant': array([0.69185597, 0.18396321]),
#  'product director - tg': array([-0.73619193,  0.03909716]),
#  'tool support specialist': array([-0.34562868,  0.69190788]),
#  'trade director management coach': array([-0.41561532,  0.73858643]),
#  'artiste technicien(informatique)': array([0.3848781 , 0.16333331]),
#  'associate producer(informatique)': array([-0.07666489,  0.77436864]),
#  'incident response project manager': array([ 0.67697006, -0.49044976]),
#  'directeur - studio son': array([0.4645257 , 0.55623221]),
#  'directeur laboratoire playtest': array([0.71902919, 0.09792801]),
#  'user research lab team lead': array([ 0.08070644, -0.86191946]),
#  'instructor(gestion)': array([0.59509754, 0.02907632]),
#  'production director - services': array([ 0.60192108, -0.09034664]),
#  'prototypeur(design)': array([-0.33695388,  0.66686273]),
#  'project lead - level design(gestion)': array([0.00286507, 0.75916785]),
#  'assistant de production(services support)': array([0.55641562, 0.50545675]),
#  'conseiller affaires corpo': array([ 0.2440432 , -0.19166222]),
#  'research and development scientist': array([ 0.35610279, -0.11073086]),
#  'product manager uplay(services professionnels)': array([ 0.37642473, -0.49969894]),
#  'coordonnateur production-video(services support)': array([0.09223939, 0.68603587]),
#  'paymaster': array([-0.03666461, -0.20404293]),
#  'live producer': array([-0.85957688,  0.13546461]),
#  'stag commis administratif': array([0.12571713, 0.75448269]),
#  'responsable - réseaux': array([-0.3362653 , -0.18218811]),
#  'strateg innovation lab manager': array([-0.08362687, -0.20138893]),
#  'analyste systèmes - gns': array([-0.74123001,  0.05238444]),
#  'technical director - design(informatique)': array([-0.03394487, -0.19936816]),
#  'erp project manager': array([-0.59434319, -0.61319107]),
#  'associate producer(contrôle qualité)': array([0.60448861, 0.43988883]),
#  'linux architect': array([-0.74723351,  0.0810144 ]),
#  'it services technical lead': array([0.04702801, 0.76846898]),
#  'quality assurance analyst': array([ 0.32376349, -0.04422176]),
#  'camera specialist': array([0.63243341, 0.33597463]),
#  'directeur - artistique cgi': array([-0.03537741, -0.19969343]),
#  'level designer(tools automation)': array([-0.22599117,  0.14462037]),
#  'it operations manager': array([ 0.16028139, -0.83072889]),
#  'director, strategic talent planning': array([0.58128428, 0.46774718]),
#  'acquisition manager': array([0.56388623, 0.46592709]),
#  'google compliance specialist team lead': array([0.08749887, 0.76409525]),
#  'cp éclairagiste': array([ 0.0209863 , -0.19900829]),
#  'human resources director(gestion)': array([ 0.47680953, -0.45770904]),
#  'associate user experience director': array([ 0.00054672, -0.37269115]),
#  'audio technical director': array([-0.78588778, -0.26517138]),
#  'live operations manager(gestion)': array([-0.79805744, -0.25973189]),
#  'commis aux achats': array([-0.33937603,  0.64550966]),
#  'prod center - document coord': array([-0.39633146, -0.69192863]),
#  'vp head of trademark & intellectual property': array([-0.21945827, -0.1229351 ]),
#  'tax director': array([ 0.59574461, -0.01763334]),
#  'adjoint -dir créatif de marque(services professionnels)': array([-0.50635988,  0.20304292]),
#  'poject manager - database administrator': array([-0.82912683,  0.22184582]),
#  'bi program manager': array([-0.04641208, -0.1978249 ]),
#  'narrative talent operations director': array([-0.35797825,  0.62916005]),
#  'team lead reception': array([-0.41120353, -0.71851015]),
#  'dev ops manager': array([-0.73187011,  0.02706593]),
#  'director, hr & comm innovation atelier': array([ 0.71192878, -0.42333856]),
#  'development manager': array([-0.24788406,  0.6958456 ]),
#  'it portfolio analyst': array([ 0.77279425, -0.04147087]),
#  'scriptwriter': array([0.57266486, 0.50506926]),
#  'finance, team lead': array([-0.25721976,  0.03057807]),
#  'strategic planning manager': array([-0.2604447 ,  0.03457809]),
#  'directeur comm externes & rp': array([-0.73139954, -0.03431166]),
#  'game system support specialist': array([-0.03919058, -0.20248929]),
#  'operations coordinator - helix': array([-0.01035993, -0.20015363]),
#  'expert community': array([-0.33668053,  0.67021221]),
#  'human resources coordinator': array([0.1062291, 0.7670849]),
#  'level designer(services professionnels)': array([ 0.28042063, -0.16778663]),
#  'technical designer': array([-0.3554073 ,  0.64480722]),
#  'audio supervisor': array([0.524059  , 0.40857375]),
#  'web developer(services professionnels)': array([0.53943968, 0.47527665]),
#  'directeur editorial gamescript(design)': array([-0.34872559,  0.6390909 ]),
#  'video specialist': array([ 0.23470058, -0.10766164]),
#  'technical director - design': array([0.58722895, 0.48565388]),
#  'coord - rémunération et sirh(services professionnels)': array([-0.74137533,  0.05688621]),
#  '3d team lead': array([ 0.17052367, -0.83394003]),
#  'graphic design team lead': array([-0.33099189,  0.70109826]),
#  'team lead sécurité': array([-0.07905245, -0.19980069]),
#  'ergonomist manager': array([-0.0430349 , -0.20284224]),
#  'project lead - graphic': array([ 0.7900781, -0.1312881]),
#  'legal adviser(autres)': array([0.75241351, 0.00813846]),
#  'instructor(services professionnels)': array([0.22001882, 0.73830611]),
#  'it portfolio manager': array([-0.06192776, -0.20057578]),
#  'hr.comm brand manager': array([0.02207974, 0.78587049]),
#  'trademark and ip manager': array([-0.07211815, -0.19880068]),
#  'cm/cs specialist': array([ 0.76677001, -0.03245697]),
#  'director - level design(artistique)': array([-0.03234278, -0.19978338]),
#  'generalist programmer(tools automation)': array([-0.0421387 , -0.20293565]),
#  'purchasing technician': array([-0.27952096,  0.4931176 ]),
#  'service director': array([0.46742192, 0.55080658]),
#  'coord - bureau de projets(gestion)': array([-0.29923043,  0.76597416]),
#  'associate world director': array([0.58151269, 0.47302401]),
#  'deputy director - tg': array([-0.63274831, -0.56419766]),
#  'specialist, platform': array([0.36372569, 0.08878262]),
#  'business development director': array([ 0.04733597, -0.1909598 ]),
#  'director codev outsourcing': array([-0.06865446, -0.20071764]),
#  'gestionnaire int/externalisation': array([-0.41342846,  0.63721895]),
#  'project & account manager': array([ 0.257853  , -0.74472487]),
#  'gns deputy director - financial operations': array([ 0.03512481, -0.19059648]),
#  'product manager - programming': array([-0.3313933 ,  0.71865892]),
#  'team lead support technique(services professionnels)': array([-0.02352957, -0.45393047]),
#  'intern - programmer(services support)': array([-0.44909653, -0.69812244]),
#  'operations director, workplace environment': array([0.75940663, 0.01649146]),
#  'cp groupe technologique(services professionnels)': array([0.71233708, 0.11791085]),
#  'collaboration tools specialist': array([-0.05575125, -0.20074533]),
#  'game designer(services support)': array([-0.73273516,  0.03000367]),
#  'quality control director': array([-0.05523913, -0.20216402]),
#  'it operations director': array([ 0.01177171, -0.425432  ]),
#  'quality assurance manager': array([ 0.04874082, -0.85690904]),
#  'directeur technique - ubik': array([-0.25752774,  0.03429089]),
#  '3s director': array([-0.55084461, -0.62898701]),
#  '3d programming team lead': array([-0.84563559,  0.12268597]),
#  'accountant(services support)': array([-0.87181914, -0.23765908]),
#  'gns director-ncsa': array([ 0.79362142, -0.11579318]),
#  'senior hr adviser': array([ 0.29505047, -0.15185918]),
#  'team lead tools automation(informatique)': array([ 0.39134181, -0.66626066]),
#  'technical director - character': array([ 0.34194353, -0.64797682]),
#  'music label manager': array([-0.26234782,  0.00889625]),
#  'director of finance(gestion)': array([0.655963  , 0.12168942]),
#  'coordonateur de franchise': array([-0.42855659, -0.17439567]),
#  'game analytics manager': array([-0.92381954,  0.23990823]),
#  'spécialist utilisabilité (que)(services support)': array([-0.18334383, -0.82459736]),
#  'content specialist': array([-0.32403338,  0.72345829]),
#  'director of dna': array([-0.04747092, -0.20064498]),
#  'gestionnaire produit it': array([0.41590253, 0.57940191]),
#  'internal community specialist': array([0.71308798, 0.1132776 ]),
#  'actor and talent management team lead': array([-0.04165081, -0.84864599]),
#  'cmk senior manager': array([-0.8674593 ,  0.14270341]),
#  'tracker': array([0.04555395, 0.79161447]),
#  'art/animation trade director': array([0.66056162, 0.24364182]),
#  'directeur mocap(services professionnels)': array([-0.2206209 , -0.80309206]),
#  '2d-3d artist': array([0.49424562, 0.54293799]),
#  'strategic talent planning manager': array([-0.26178035,  0.0262943 ]),
#  'user research lab manager': array([ 0.581267 , -0.2161572]),
#  'stock and inventory specialist': array([ 0.55502111, -0.28368708]),
#  "chef d'équipe compatibilité": array([-0.03979958, -0.20517443]),
#  'technical director - animation(services professionnels)': array([-0.84626883,  0.0029412 ]),
#  'animation programmer': array([-0.35501629,  0.66789389]),
#  'fiscal & subsidies analyst': array([ 0.29031688, -0.68448913]),
#  'systems analyst - oracle': array([-0.15454432, -0.83500576]),
#  'intern - programmer': array([0.53044313, 0.48780268]),
#  'web designer(informatique)': array([0.29261795, 0.56767172]),
#  'narrative director': array([0.49190304, 0.52978218]),
#  'production manager - it': array([ 0.2180361 , -0.21483539]),
#  'audio director': array([0.5097267 , 0.48731479]),
#  'content strategist': array([ 0.08249538, -0.3062824 ]),
#  'production manager - it(gestion)': array([-0.05895196, -0.20056194]),
#  'esports director': array([-0.74971795,  0.09128091]),
#  '2d compositor': array([-0.11190388,  0.7649672 ]),
#  'technicien son': array([-0.06121841, -0.20092526]),
#  'it architect': array([-0.33905771,  0.67082816]),
#  'product director - mkg': array([ 0.43455318, -0.43988883]),
#  'dt team lead': array([-0.56530148, -0.02378217]),
#  'production business analyst(services professionnels)': array([-0.33410612,  0.69431275]),
#  'security and risk management director': array([-0.34035876,  0.65560663]),
#  'team lead maintenance': array([-0.04004872, -0.20280762]),
#  'technical service manager': array([ 0.63661337, -0.56679976]),
#  'directeur des opérations': array([-0.05400383, -0.20359311]),
#  'production assistant (tor)': array([-0.06659908,  0.76897073]),
#  'exp prod tech': array([-0.04295185, -0.19941314]),
#  'game release specialist': array([ 0.00794123, -0.85911667]),
#  'development tester': array([-0.26038933, -0.05506266]),
#  'development team lead': array([-0.34174976,  0.65398377]),
#  'talent acquisition coordinator': array([ 0.02774068, -0.19281448]),
#  'vice president, it infrastructure and operations': array([-0.75221628, -0.24585983]),
#  'director, talent development strategy': array([0.58225316, 0.48798606]),
#  "coord - système d'information(services support)": array([-0.29628578, -0.77980471]),
#  'generalist programmer(it corpo)': array([0.71730596, 0.06620115]),
#  'directeur services audio (qc)': array([ 0.15072769, -0.84604388]),
#  'brand producer': array([ 0.68868989, -0.46652225]),
#  'mocap shoot manager': array([-0.1037585 , -0.19260341]),
#  'graphic designer': array([ 0.68783176, -0.47893065]),
#  'recruitment manager': array([0.00666095, 0.77209526]),
#  'coord support technique(services professionnels)': array([ 0.66685581, -0.51518005]),
#  'business travel coordinator': array([-0.03786185, -0.8514626 ]),
#  'localization manager': array([-0.35508895,  0.63026732]),
#  'online game tech ops manager': array([-0.66593885,  0.38718259]),
#  'programming team lead': array([-0.8686046 ,  0.07643998]),
#  'technical writer': array([0.72481471, 0.10319448]),
#  'tool support specialist(dev test)': array([-0.65033668, -0.44813457]),
#  'artiste technicien(artistique)': array([-0.71842021,  0.00994817]),
#  'directeur academia': array([0.68118119, 0.17110153]),
#  'team lead': array([0.51606584, 0.51209348]),
#  'dir artistique communication(services professionnels)': array([ 0.18893211, -0.25930282]),
#  'gestionnaire de projets sr(informatique)': array([-0.01091703,  0.76929599]),
#  'exp research': array([0.11551291, 0.75678378]),
#  'video team lead(services professionnels)': array([-0.34086394,  0.65708065]),
#  'associate monetization director': array([-0.05563014, -0.20449276]),
#  'lead release and build': array([-0.03301061, -0.20309137]),
#  'associate tgo director': array([0.37387109, 0.66905308]),
#  'senior advisor - corporate affairs': array([0.04970969, 0.76931328]),
#  'chef projet qa': array([0.5840767 , 0.47031119]),
#  'hr business analyst(services professionnels)': array([ 0.11857867, -0.28204691]),
#  'analyst senior - cmk': array([-0.2623063 , -0.03346736]),
#  'microsoft  architect(services professionnels)': array([-0.7887736 ,  0.11196271]),
#  'responsable développement .net': array([0.54740518, 0.34510273]),
#  'lighter': array([-0.29182208,  0.74267983]),
#  'web integrator(artistique)': array([-0.26559353, -0.03191026]),
#  'artistic director': array([-0.34541762,  0.66574854]),
#  'technical lead': array([ 0.17644066, -0.41845962]),
#  'tools programmer': array([0.58143997, 0.47348425]),
#  'assistant executive producer': array([0.53086179, 0.50036329]),
#  'talent acquisition specialist': array([0.70158267, 0.15167579]),
#  'data scientist': array([-0.30788794, -0.12747146]),
#  'security analyst(informatique 35 hrs)': array([ 0.77006412, -0.04521484]),
#  'entraîneur(services professionnels)': array([-0.05278929, -0.19898753]),
#  'audio programmer': array([ 0.02308667, -0.39884013]),
#  'directeur métier - animation(artistique)': array([ 0.27987045, -0.1730704 ]),
#  'commis comptable': array([-0.30738619,  0.74865913]),
#  'executive director, studio production': array([ 0.60687613, -0.48599988]),
#  'cloud developer': array([-0.78123724,  0.19114664]),
#  'players communication manager': array([ 0.10200763, -0.32119945]),
#  'operations and it production manager': array([-0.58883798, -0.63889712]),
#  'observateur(autres)': array([-0.26129591, -0.00106229]),
#  'directeur - cq monde(gestion)': array([ 0.32492957, -0.7982685 ]),
#  'base camp animator': array([-0.74464875,  0.06693818]),
#  'product manager uplay(informatique)': array([-0.26306757,  0.01296895]),
#  'monetization specialist': array([-0.61056131, -0.60544014]),
#  'operations manager workplace': array([0.05680316, 0.7207005 ]),
#  'programming team lead(it corpo)': array([0.63864106, 0.3561824 ]),
#  'digital solutions analyst': array([-0.41414472,  0.62639534]),
#  'assistant technical director - graphic': array([ 0.24157606, -0.61938143]),
#  'director of finance': array([-0.37687457,  0.62800086]),
#  'risk management specialist': array([-0.26339629, -0.08386563]),
#  'cp game ops(informatique)': array([-0.73304313,  0.39211342]),
#  'production project manager(informatique)': array([-0.27836871, -0.12609084]),
#  'production manager(design)': array([-0.72692889,  0.02073717]),
#  'technical lead(it corpo)': array([-0.34765291,  0.66395265]),
#  'analytics team lead': array([-0.73840648,  0.04622869]),
#  'cp groupe technologique(informatique)': array([ 0.35362872, -0.08921861]),
#  'developer relationship manager': array([-0.05618378, -0.20206022]),
#  'director - tgo': array([ 0.36037272, -0.08241233]),
#  'security analyst(contrôle qualité)': array([-0.92862922,  0.30575991]),
#  'lead security architect': array([ 0.17183509, -0.82572544]),
#  'programming trade director': array([0.60493499, 0.45808619]),
#  'vp adjoint ressources humaines': array([ 0.62101811, -0.5919522 ]),
#  'coordonnateur recrutement': array([-0.27671471, -0.07427387]),
#  'transmedia and business development director': array([-0.4076637 ,  0.62666523]),
#  'responsable helpdesk(services professionnels)': array([-0.84785706,  0.20417096]),
#  'tg director -tools & middleware': array([-0.07176174, -0.20369691]),
#  'design/audio trade director': array([0.55528063, 0.31423053]),
#  'hr business analyst': array([-0.2994242 ,  0.76325786]),
#  'qa technical analyst': array([-0.06765445, -0.20067959]),
#  'directeur syst exploitation': array([-0.85532427,  0.16118796]),
#  'marketing & communication manager': array([ 0.2638911 , -0.18761028]),
#  'manager km services': array([ 0.78871477, -0.16844061]),
#  'localization director(services professionnels)': array([ 0.0269033 , -0.33315802]),
#  'hr partner': array([ 0.17047869, -0.83894002]),
#  'stagiaire(informatique)': array([ 0.42171916, -0.47650847]),
#  'bi director': array([ 0.40524846, -0.15944055]),
#  'dir adjoint it - services': array([ 0.60324293, -0.08083793]),
#  'music supervisor': array([ 0.06143641, -0.1878006 ]),
#  'data architect': array([ 0.26825792, -0.73436493]),
#  'technical lead(artistique)': array([-0.86179143,  0.14976227]),
#  'integrator': array([-0.00122838, -0.19915362]),
#  'technicien support applicatif': array([-0.28920615,  0.76935828]),
#  'assistant technical director - level design': array([ 0.15446819, -0.15010831]),
#  'tools tester(informatique)': array([-0.73117113,  0.02577526]),
#  'music department coordinator': array([-0.84134489, -0.16946137]),
#  'director - corporate affairs': array([-0.62343335,  0.49680966]),
#  'it production coordinator(services professionnels)': array([0.54354006, 0.46127653]),
#  'rigger': array([-0.72109842, -0.02327006]),
#  'audio artist': array([ 0.22837181, -0.77389115]),
#  'analytics process lead': array([0.60580003, 0.43729714]),
#  'logistics clerk': array([-0.05011453, -0.20674883]),
#  'mocap supervisor(services professionnels)': array([0.48920754, 0.53268188]),
#  'cloud infrastructure  analyst': array([-0.26270768,  0.02262299]),
#  'cloud administrator': array([-0.39959791,  0.64587641]),
#  'lead audio designer': array([-0.33870822,  0.66432983]),
#  'graphic design team lead - helix': array([ 0.26530978, -0.14243697]),
#  'human resources officer': array([-0.26298451,  0.0152008 ]),
#  'technical artist': array([-0.73499471,  0.03610406]),
#  'director of online experience - harbour': array([-0.06347795, -0.20018823]),
#  'technical director - cgi': array([ 0.76545513, -0.21578349]),
#  'technical operations director': array([ 0.43347013, -0.87444204]),
#  'tracking specialist team lead': array([0.6601845 , 0.29872179]),
#  'webmestre': array([-0.34773943,  0.65037817]),
#  'responsable ibsa': array([0.56868213, 0.48191336]),
#  'pipeline director': array([0.52186865, 0.42396486]),
#  'mixeur & preneur de son(artistique)': array([ 0.18638884, -0.81877381]),
#  'chargé opération ctr formation': array([-0.25831321, -0.05219413]),
#  'business solutions architect': array([-0.25823361,  0.01639804]),
#  'executive director - operations(gestion)': array([-0.4036983 ,  0.62780362]),
#  'sound technician': array([ 0.73628885, -0.37635899]),
#  'cp livrables(services professionnels)': array([-0.04378577, -0.19763803]),
#  'music dpt & label coordinator': array([0.75568342, 0.00762981]),
#  'directeur réseaux monde(autres)': array([0.75889796, 0.00101385]),
#  'talent network recuitment': array([-0.01918352, -0.20036124]),
#  'product manager tech. group(informatique)': array([-0.04033592,  0.77042747]),
#  'global compensation advisor': array([-0.86114436,  0.1886622 ]),
#  'associate game director': array([-0.42872268, -0.69213629]),
#  'operations and logistics supervisor': array([-0.04455048,  0.77635831]),
#  'physical security operations manager': array([-0.25962809, -0.01723195]),
#  'associate product manager - mkg': array([-0.35403359,  0.63695943]),
#  "chef d'équipe outils partage": array([-0.62775868, -0.62846106]),
#  'community developer senior': array([ 0.29330307, -0.15963778]),
#  "chef d'équipe ass qualité": array([-0.31508175,  0.73379743]),
#  'dir dévelop cross media': array([0.5675506 , 0.19516052]),
#  'vp of production intelligence': array([-0.06881016,  0.65169656]),
#  'project lead - level design': array([-0.56204194,  0.09830517]),
#  'communications project manager': array([-0.04006256, -0.20427823]),
#  'director, culture & special projects': array([-0.06168901, -0.19481796]),
#  'bi developer': array([ 0.02647423, -0.33631721]),
#  'compensation coordinator': array([ 0.36444196, -0.09279995]),
#  'vice president, general manager': array([ 0.14412211, -0.84895396]),
#  'artistic director - helix': array([0.2610468, 0.7277559]),
#  'research and analytics specialist': array([0.52764726, 0.44709998]),
#  'gns project coordinator(gestion)': array([-0.02718358, -0.52907288]),
#  'directeur editorial gamescript(artistique)': array([ 0.0456889 , -0.86641079]),
#  'n/a.animateur()': array([ 0.59692109, -0.12022574]),
#  'customer lifecycle manager': array([-0.26009867,  0.03464384]),
#  'studio production manager': array([-0.61639869, -0.57889324]),
#  'directeur adjoint gns': array([-0.03683417, -0.20015018]),
#  'event scripter': array([ 0.15222943, -0.851601  ]),
#  'lead technique ubik': array([0.44031444, 0.57560951]),
#  'associate narrative director': array([-0.01730462, -0.20370382]),
#  'project closer': array([-0.26700529, -0.69371068]),
#  'advisor - corporate affairs': array([-0.46597207, -0.64297676]),
#  'conseiller comm et réseautage(services professionnels)': array([-0.34619269,  0.44489235]),
#  'ergonomist(services professionnels)': array([-0.01312466, -0.19971073]),
#  'gameplay camera specialist': array([-0.25915056,  0.01962989]),
#  'senior producer': array([-0.8400473 ,  0.21507069]),
#  'architecte outils de partage': array([ 0.34457332, -0.67306691]),
#  'it process analyst': array([ 0.14840241, -0.84463215]),
#  'business analyst': array([0.69841313, 0.17353407]),
#  'dt prod pipeline (que)(gestion)': array([ 0.69693214, -0.44875395]),
#  'brand director': array([-0.0520834, -0.4314805]),
#  'operations and logistics coordinator': array([ 0.59290028, -0.15835057]),
#  'virtualization administrator(informatique)': array([ 0.77257973, -0.0540419 ]),
#  'dir métier / coach en gestion': array([ 0.27279082, -0.17049944]),
#  'uor/network specialist team lead': array([ 0.31499872, -0.38866013]),
#  'responsable contenu - marque*(design)': array([-0.28472862,  0.55729449]),
#  'exp prod anim': array([ 0.24105357, -0.20945819]),
#  'generalist programmer': array([-0.32835174, -0.16308764]),
#  'technical lead – hardware': array([ 0.75553811, -0.00477858]),
#  'animation team lead': array([-0.41628316,  0.65734363]),
#  'purchasing operations team lead': array([-0.01786518,  0.77370429]),
#  'game designer(contrôle qualité)': array([0.399937  , 0.57445723]),
#  'tg coordinator': array([-0.84591931, -0.03105212]),
#  'projects & accounts manager': array([-0.74393594, -0.43112409]),
#  'logistics team lead': array([-0.8523069 ,  0.12466176]),
#  'technicien - stechnique sr(services professionnels)': array([-0.08197288, -0.20201524]),
#  'director - digital affairs': array([ 0.03707292, -0.85631388]),
#  'accountant': array([-0.01868179, -0.86360455]),
#  'hris coordinator': array([ 0.21739596, -0.21245821]),
#  'executive assistant(services professionnels)': array([-0.76725441,  0.15337822]),
#  'hr and communications executive director': array([-0.41972607,  0.6384058 ]),
#  'international mobility technician': array([0.74567294, 0.02841888]),
#  'hr manager junior': array([-0.8704316 ,  0.05551595]),
#  'trade community developer': array([-0.05706268, -0.2031675 ]),
#  'conseiller communications ext': array([-0.08672724, -0.20052041]),
#  'knowledge management project manager': array([-0.3146354 ,  0.74224043]),
#  'payroll coordinator': array([ 0.25555885, -0.18449955]),
#  'dir adjoint it - opérations': array([-0.00381664, -0.19837508]),
#  'directeur - ressources humaine': array([ 0.02513512, -0.19527124]),
#  'game designer(informatique)': array([ 0.18684211, -0.80814743]),
#  'market & media analyst': array([ 0.78847605, -0.11762711]),
#  'director - helix': array([-0.04639132, -0.19462764]),
#  'directeur sce à la prod & it': array([-0.05043979, -0.20546162]),
#  'responsable prod animation': array([0.5824815, 0.0072215]),
#  'analytics director': array([-0.87910295,  0.13086942]),
#  'game intelligence analyst': array([-0.85676718,  0.07213198]),
#  'coach - dir métier': array([-0.53066456,  0.61375165]),
#  "spécialiste de l'intégration": array([ 0.54510754, -0.24685983]),
#  'pmo manager': array([0.55144674, 0.52216625]),
#  'directeur créatif - ubik': array([ 0.79833078, -0.17432646]),
#  'human resources advisor': array([0.56219763, 0.24875604]),
#  'product manager tech group(design)': array([0.53940165, 0.36712363]),
#  'associate helix studio film director': array([-0.80448997,  0.21291496]),
#  'production manager - services': array([ 0.1808836 , -0.33791929]),
#  'localization director': array([-0.86585027,  0.03925979]),
#  'spécialiste technique cgi': array([-0.8402549 ,  0.00737029]),
#  'security architect(services professionnels)': array([-0.34626192,  0.66273814]),
#  'release & build specialist(informatique)': array([-0.04085495,  0.41153917]),
#  'employer brand manager': array([0.05801424, 0.76798105]),
#  'lead programmeur ai': array([ 0.68385595, -0.48413482]),
#  'live marketing specialist': array([0.73467636, 0.06403504]),
#  'team lead accounts payable': array([-0.84071517, -0.00976131]),
#  'external communications director': array([-0.01614544, -0.19985259]),
#  'game security specialist': array([0.58854729, 0.01003813]),
#  'hr manager': array([-0.49247745,  0.65718448]),
#  'graphic trade director': array([-0.8393414 ,  0.21104644]),
#  'product manager - mkg(services support)': array([-0.05692081, -0.20242009]),
#  'live operations project manager': array([ 0.53327703, -0.31609562]),
#  'expert prod anim': array([-0.04378923, -0.49449822]),
#  'technical translator test': array([0.31084991, 0.27393615]),
#  'economic designer (qc)': array([-0.05632911, -0.19611208]),
#  'producer(producteurs)': array([-0.03954352, -0.20164153]),
#  'finance & accounting coordinator(services support)': array([-0.0641527 , -0.50905889]),
#  'data analyst(services support)': array([0.51434267, 0.51978213]),
#  'ui artist(contrôle qualité)': array([-0.28805736, -0.10194534]),
#  'r&d programmer': array([-0.84631723, -0.25491178]),
#  'stag informatique t1(autres)': array([0.01909356, 0.59519786]),
#  'directeur production(gestion)': array([-0.36726898,  0.63454074]),
#  'associate producer(services professionnels)': array([-0.34742799,  0.66295612]),
#  'sound hardware technical lead': array([ 0.158444  , -0.83905423]),
#  'senior manager cmk': array([0.53064728, 0.55223221]),
#  'production coordinator(services support)': array([-0.02122852, -0.64331239]),
#  'external communications manager': array([-0.02243614, -0.20420556]),
#  'network architect': array([ 0.13855459, -0.84785014]),
#  'chef de produit - transmedia': array([-0.38354245,  0.41060838]),
#  'artiste audio(artistique)': array([-0.07699707, -0.19616744]),
#  'security researcher': array([ 0.13083135, -0.29286361]),
#  'events security manager': array([0.63517046, 0.36781567]),
#  'licensing coordinator(services support)': array([ 0.496301  , -0.50913501]),
#  'sound designer': array([-0.74643421,  0.07772026]),
#  'vp ressources humaines(gestion)': array([0.65808415, 0.28567672]),
#  'executive producer(services professionnels)': array([ 0.04988962, -0.8522585 ]),
#  'helix studio director': array([ 0.33125833, -0.79035145]),
#  'generalist programmer(artistique)': array([ 0.23905355, -0.21282846]),
#  'music business & publish mgr': array([-0.08987951, -0.20055501]),
#  'quality control manager': array([-0.39315495,  0.62266171]),
#  'vp - rh/ affaires corporatives': array([-0.22620571, -0.12201468]),
#  'narrative director assistant(artistique)': array([-0.88267046,  0.12189011]),
#  'gestionnaire int/externalisation(services professionnels)': array([-0.17580052, -0.82511294]),
#  'database administrator': array([-0.8579402 ,  0.13187981]),
#  'administration and operations director': array([-0.19681451, -0.81289834]),
#  'sound technician(services professionnels)': array([0.67850643, 0.23449989]),
#  'editorial communication team lead': array([-0.60756475, -0.55922878]),
#  'physical security specialist': array([-0.26352084, -0.7968117 ]),
#  'administrative coordinator': array([-0.02033232,  0.77346903]),
#  'music label marketing manager': array([-0.01342916, -0.36977765]),
#  'construction project manager': array([-0.08095212, -0.20039585]),
#  'production manager(contrôle qualité)': array([0.60499728, 0.44045633]),
#  'mocap technical director': array([0.5434674 , 0.37415138]),
#  'dir marketing et com ext (que)': array([-0.05401421, -0.20263807]),
#  'security analyst(autres)': array([-0.1253192 ,  0.76276648]),
#  'director - level design': array([-0.07148492, -0.20109481]),
#  'applications administrator': array([-0.06315961, -0.20377304]),
#  'directeur - studio ubik(services professionnels)': array([-0.34999895,  0.63278639]),
#  'technical support analyst': array([ 0.23974906, -0.25329241]),
#  'producer(cadres supérieurs)': array([-0.41772953,  0.62935728]),
#  "chef d'équipe graphique - ubik": array([0.58287597, 0.48056042]),
#  "chef d'équipe support pipeline(informatique)": array([0.15008754, 0.75751388]),
#  'brand content manager': array([ 0.16448556, -0.273341  ]),
#  'live producer(design)': array([ 0.65083146, -0.45952219]),
#  'project closer(services professionnels)': array([0.57123578, 0.21284921]),
#  'dir artistique communication(artistique)': array([-0.41904441,  0.63736081]),
#  'story designer': array([ 0.42908946, -0.38603035]),
#  'instructor(design)': array([0.40638342, 0.04808684]),
#  'linux administrator(informatique)': array([-0.29455912, -0.77995002]),
#  'artiste 2d': array([-0.79251063, -0.06412155]),
#  'mocap specialist': array([-0.30022699,  0.76390147]),
#  'programmeur menus&interfa': array([-0.35507858, -0.15743016]),
#  'team lead support technique(services support)': array([ 0.76303989, -0.07610779]),
#  'development test coordinator': array([-0.32641748,  0.7308355 ]),
#  'n/a(artistique)': array([0.60670662, 0.43148741]),
#  'service delivery manager': array([ 0.54005218, -0.37581229]),
#  'operations manager serv center': array([-0.40525886,  0.63790059]),
#  'mocap studio manager': array([ 0.60016328, -0.07057488]),
#  'outsourcing production manager': array([-0.66864473, -0.03924594]),
#  'sharepoint business analyst': array([ 0.59964776, -0.04976505]),
#  'event team lead': array([-0.41554266,  0.62548184]),
#  'directeur approvisionnements': array([0.60541594, 0.4497436 ]),
#  'brand creative director': array([-0.65286261, -0.4074907 ]),
#  'directeur métier qa-tools': array([0.44492349, 0.62125689]),
#  'directeur technique model(design)': array([-0.98041505,  0.24910899]),
#  'realization director': array([0.56416655, 0.31374264]),
#  'gns global operations director': array([-0.34245911,  0.64869654]),
#  'it data analyst': array([-0.0466716 , -0.20525748]),
#  'ethical hacker': array([ 0.41062912, -0.65186608]),
#  'gns worldwide operations manager': array([-0.02983412, -0.20484224]),
#  'training coordinator(services professionnels)': array([0.66430217, 0.24017812]),
#  'coord communications gns': array([ 0.77472854, -0.06291739]),
#  'producer(services professionnels)': array([ 0.69545811, -0.45713118]),
#  'it technician': array([ 0.46474716, -0.40402356]),
#  'senior communication advisor': array([-0.41528314,  0.63337809]),
#  'legal advisor': array([-0.37792647,  0.64114285]),
#  'organizational development adviser': array([0.57774448, 0.50947756]),
#  'live content director': array([-0.05596578, -0.2025135 ]),
#  'operations executive director': array([-0.75303286,  0.1763334 ]),
#  'communications director': array([ 0.05628413, -0.3149918 ]),
#  "chef d'équipe admin rh(services support)": array([-0.63328809, -0.56305581]),
#  'associate director, music operations': array([ 0.54291379, -0.29449683]),
#  'system administrator - command center': array([ 0.3077772 , -0.71246511]),
#  'technicien - stechnique sr(services support)': array([ 0.05611803, -0.18720891]),
#  'technical director online operations': array([-0.8601374 ,  0.03001751]),
#  'entraîneur(services support)': array([-0.06136375, -0.19997716]),
#  'management control manager': array([0.579395 , 0.4617506]),
#  'kinesiologist(services support)': array([ 0.32585001, -0.63385212]),
#  'collaborative tools manager': array([-0.98311406,  0.25024047]),
#  'digital monetization operations manager': array([-0.04974083, -0.20119862]),
#  'dir productivité & qualité': array([0.53151578, 0.50947756]),
#  'stag informatique t2(autres)': array([-0.02279254, -0.20439588]),
#  'executive vice president, creation': array([ 0.77050012, -0.27592579]),
#  'acheteur biens & services(services support)': array([0.55402803, 0.49870586]),
#  'graphic design team lead(design)': array([ 0.5016886 , -0.42840433]),
#  'visual effects supervisor': array([-0.33372548,  0.69546157]),
#  'game release coordinator': array([ 0.23501892, -0.25712979]),
#  'directeur artistique - ubik': array([ 0.10977931, -0.8566668 ]),
#  'executive director - technology': array([-0.38732794,  0.62336761]),
#  'security architect': array([0.41225889, 0.65770698]),
#  'vp production': array([ 0.26157275, -0.14687298]),
#  'administrative clerk': array([ 0.06808352, -0.87396795]),
#  'acheteur informatique': array([-0.07729119, -0.19920899]),
#  'team lead online': array([-6.74745126e-04, -8.52137387e-01]),
#  'chef groupe-marketing': array([-0.037457  , -0.40103737]),
#  'camera specialist(gestion)': array([ 0.7705797 , -0.18178672]),
#  'busdev manag codev outsourcing(services professionnels)': array([-0.55044323, -0.62927425]),
#  'contrat director': array([-0.24238229, -0.03493796]),
#  'aide au magasinier': array([ 0.17977978, -0.82319254]),
#  'user research project manager': array([ 0.58054036, -0.1589838 ]),
#  'technical director - animation': array([ 0.40401661, -0.44782662]),
#  'recruitment and international mobility coordinator': array([-0.39953908, -0.71309835]),
#  'directeur - cq monde(producteurs)': array([0.75709522, 0.00277511]),
#  'camera specialist - cinematics(artistique)': array([ 0.08263379, -0.86277068]),
#  'finance & accounting coordinator(services professionnels)': array([0.68565524, 0.16775894]),
#  'coord production - transmedia(services support)': array([-0.39556673,  0.62610465]),
#  'game design team lead': array([0.60884851, 0.43639401]),
#  'special projects coordinator': array([0.5935508 , 0.45459136]),
#  'matte painter': array([-0.39120686,  0.62805969]),
#  'cp compositing': array([-0.64440238, -0.67264479]),
#  'localization advisor': array([ 0.56125647, -0.34026188]),
#  'production coordinator(tools automation)': array([-0.55704188, -0.09281033]),
#  'live operations manager': array([-0.06899355, -0.20429899]),
#  'development director': array([-0.42173994,  0.63630891]),
#  'director of technological operations': array([-0.30725124, -0.12664448]),
#  'mocap technician(informatique)': array([-0.37575346,  0.71858972]),
#  'coord production - transmedia(services professionnels)': array([-0.37671539,  0.64565152]),
#  'directeur mocap(artistique)': array([-0.25937548,  0.04059197]),
# ...
#  'responsable - achats': array([-0.41219661,  0.6286099 ]),
#  'associate presentation director': array([ 0.15550627, -0.14974844]),
#  'technical director - pipeline': array([-0.65795612, -0.42241123]),
#  'executive vice president, technology': array([-0.82461816, -0.26279074]),
#  'monteur cinématique(artistique)': array([-0.05700731, -0.20226783]),
#  'architecte technique - it': array([-0.00586509, -0.19963805]),
#  'client manager': array([ 0.59178609, -0.18326424]),
#  'coordonnateur production-video(services professionnels)': array([ 0.39953908, -0.46400666]),
#  'production manager - helix': array([-0.26378381,  0.00363324]),
#  'music licensing director': array([-0.70857584,  0.41531429]),
#  'responsable développement net': array([-0.73784935,  0.04422176]),
#  'administrative technician': array([-0.71785271,  0.00885127]),
#  'ergonome-prod(services professionnels)': array([-0.06375822, -0.1988249 ]),
#  'team lead, architect': array([ 0.38310644, -0.67663443]),
#  'purchasing team lead(services professionnels)': array([-0.84126532,  0.15779348]),
#  'gestionnaire de projets sr(services professionnels)': array([ 0.55667859, -0.63963765]),
#  'tg coordinator(services support)': array([ 0.6807763 , -0.48761237]),
#  'technical director - pipeline(gestion)': array([0.0562599 , 0.76411945]),
#  'functional analyst': array([0.14766538, 0.75194639]),
#  'programmeur framework': array([-0.2604101 , -0.06419422]),
#  'observateur(services professionnels)': array([-0.82584655, -0.26050353]),
#  'directeur - dév des affaires': array([0.58794177, 0.46424195]),
#  'trade community developer(design)': array([-0.25936165,  0.03581339]),
#  'level design team lead(artistique)': array([-0.05767514, -0.20494258]),
#  'user experience director': array([-0.25916097, -0.00646717]),
#  'directeur réseaux monde(services professionnels)': array([ 0.03558156, -0.86121702]),
#  'adjoint -dir créatif de marque(design)': array([-0.78887051,  0.20129551]),
#  'vp éditorial(autres)': array([0.49921104, 0.53209364]),
#  'ui artist(informatique)': array([-0.53195524, -0.05511803]),
#  'sound team lead': array([0.71840978, 0.09874809]),
#  'analyste - plan de ressources': array([0.12265483, 0.66501153]),
#  'sales manager': array([-0.33826184,  0.65324324]),
#  'production manager(artistique)': array([0.5079447 , 0.52091014]),
#  'pipeline director(gestion)': array([-0.07901438, -0.19988719]),
#  'project lead - qc': array([-0.51576829,  0.20480072]),
#  'compositing team lead': array([-0.02674413,  0.77070081]),
#  'producer': array([ 0.38724488, -0.60985541]),
#  'marketing game manager(services professionnels)': array([-0.8513242 ,  0.22732683]),
#  'coord - opération & logistique(services support)': array([-0.34033799,  0.65688342]),
#  'live services director': array([ 0.07602821, -0.18401857]),
#  'qa programmer': array([-0.363307,  0.660707]),
#  'executive director': array([-0.03164382, -0.19988373]),
#  'responsable logistique': array([ 0.3497498 , -0.09469269]),
#  'web designer(tools automation)': array([-0.04670274, -0.19915709]),
#  'trademark counsel assistant': array([-0.82582229, -0.26341012]),
#  'team lead stockroom': array([-0.76048273,  0.12874137]),
#  'tester(informatique)': array([ 0.33812344, -0.5725714 ]),
#  'data center technician': array([ 0.76847589, -0.02374065]),
#  'gest subventions & processus': array([ 0.70657927, -0.4020789 ]),
#  'conseiller en fiscalité': array([0.51323885, 0.29075634]),
#  'analyst programmer': array([-0.05383774, -0.20546162]),
#  'directeur dev et recherche(services professionnels)': array([-0.05250209, -0.20480418]),
#  'designer infographiste ubik': array([-0.05025294, -0.85608894]),
#  'employee relations partner': array([-0.07702129, -0.19909135]),
#  'release & build specialist': array([ 0.74630618, -0.19450653]),
#  'directeur comm externes & rel': array([0.57612854, 0.46366408]),
#  'game monetization & bi manager(gestion)': array([-0.01166098, -0.20039585]),
#  'game designer(gestion)': array([0.72760016, 0.07994519]),
#  'customer relationship management (crm) integrator': array([-0.31243122, -0.17111883]),
#  'logistics coordinator(services professionnels)': array([ 0.74894291, -0.3030782 ]),
#  'busdev manag codev outsourcing(gestion)': array([ 0.06418037, -0.67913616]),
#  'lead analyste antipiratage': array([-0.01101392, -0.36729667]),
#  'brand analytics manager': array([-0.25837895,  0.03154693]),
#  'audio designer': array([-0.79026496,  0.20384569]),
#  'data center supervisor': array([-0.80091554, -0.32827562]),
#  'project lead - animation': array([ 0.35709244, -0.1249628 ]),
#  'directeur sirh': array([ 0.03567499, -0.19308783]),
#  'codev outsourcing communication manager': array([0.58974457, 0.05083772]),
#  'cg supervisor': array([-0.40031764, -0.20791146]),
#  'lead mocap specialist': array([-0.04823217, -0.57011813]),
#  'team lead quality assurance - operations': array([-0.22405691,  0.62857181]),
#  'online programmer': array([-0.0427823 , -0.20155156]),
#  'production manager - it(services professionnels)': array([ 0.24311933, -0.24844116]),
#  'codev outsourcing studio manager': array([-0.26855204, -0.10893847]),
#  'gns deputy director': array([-0.05277891, -0.20269343]),
#  'technology director': array([-0.00436681, -0.85355258]),
#  'game director': array([-0.47440121, -0.17884207]),
#  'online achitect (gns)(services professionnels)': array([0.74084246, 0.03527014]),
#  'technical director - graphic': array([-0.84201968,  0.18596321]),
#  'actor and talent management specialist': array([-0.36497483,  0.66199768]),
#  'social media project manager': array([0.43830061, 0.55929452]),
#  'interface developer(artistique)': array([ 0.70864159, -0.42622787]),
#  'directeur de projets - ubik': array([-0.06493817,  0.76864547]),
#  'project & account manager(informatique)': array([0.53895873, 0.52868187]),
#  'int product manager(services support)': array([-0.04193109, -0.20285261]),
#  'communication artist(services professionnels)': array([-0.0418515 , -0.19892524]),
#  'online systems architect': array([0.64225012, 0.30135155]),
#  'purchasing director': array([ 0.24960034, -0.18698744]),
#  'user research process lead': array([-0.43585077, -0.64674497]),
#  'vp, editorial': array([0.54216981, 0.45082319]),
#  'producer(informatique)': array([ 0.24342729, -0.24161412]),
#  'security information coordinator': array([ 0.47626972, -0.83793658]),
#  'assistant dt cgi': array([0.68797708, 0.17623305]),
#  'technical architect': array([0.53025281, 0.32795727]),
#  'technical architect(informatique 35 hrs)': array([ 0.64141273, -0.559035  ]),
#  'lead community developer': array([ 0.09529132, -0.85644537]),
#  'chairman and chief executive officer': array([0.60129827, 0.43857396]),
#  'product specialist - professional': array([ 0.77099842, -0.1796483 ]),
#  'film director(artistique)': array([0.49478543, 0.5352667 ]),
#  'monetization director': array([-0.33917534,  0.65492493]),
#  'production coordinator': array([0.76085991, 0.00520765]),
#  'consultant': array([0.55442595, 0.51603472]),
#  'online operation developer': array([-0.31477726,  0.73750681]),
#  'procurement & it director': array([-0.06238451, -0.21471082]),
#  'scriptwriter(services professionnels)': array([0.63613588, 0.36297482]),
#  'managing director': array([-0.86397827,  0.15305296]),
#  'applications and infrastructures security manager': array([ 0.33520648, -0.10823258]),
#  'process & portfolio manager': array([-0.39277434,  0.63425696]),
#  'product manager - mkg(gestion)': array([-0.2637077 ,  0.01616274]),
#  'product specialist - programming': array([0.51547068, 0.50251555]),
#  'sony compliance specialist tester': array([0.44566399, 0.57144684]),
#  'backup and storage architect(services professionnels)': array([0.35624123, 0.68712586]),
#  'ui programmer': array([ 0.54922175, -0.27433407]),
#  'it & logistics director': array([0.57514584, 0.46154296]),
#  'backup and storage administrator(informatique)': array([-0.85997826,  0.13995944]),
#  'directeur - dotation': array([0.11112534, 0.76239628]),
#  'director': array([-0.26784268, -0.03458155]),
#  'perf capt pipeline specialist(informatique)': array([-0.02621471, -0.20289068]),
#  'senior development manager': array([ 0.33996776, -0.69618475]),
#  'compensation coordinator(services support)': array([0.45681977, 0.59038126]),
#  'music operations director': array([ 0.21851015, -0.138475  ]),
#  'music business & supervision director': array([-0.30576336,  0.75039274]),
#  'licensing coordinator': array([-0.30802634,  0.76406753]),
#  'mixeur & preneur de son(services professionnels)': array([ 0.33664247, -0.3359504 ]),
#  'director of real estate and procurement': array([-0.5318203 , -0.64269304]),
#  'localization project manager(tools automation)': array([-0.40702358,  0.62537456]),
#  'executive vice president, production': array([-0.85219276,  0.12332265]),
#  'team lead - tech mocap': array([-0.06793472, -0.19945812]),
#  'security analyst(services professionnels 35 hrs)': array([ 0.42691299, -0.47276103]),
#  'responsable localisation': array([0.5933882 , 0.47314858]),
#  'production coordinator(contrôle qualité)': array([-0.73666596,  0.04045357]),
#  'directeur métier - design(gestion)': array([-0.00525955, -0.19763458]),
#  'tax and grants manager': array([ 0.3866255 , -0.65311867]),
#  'vice president, creation': array([-0.556817  , -0.62707698]),
#  'tools developer': array([-0.0559554 , -0.20221938]),
#  'programming trade director(informatique)': array([-0.01212465, -0.19984913]),
#  'it manager': array([-0.53003824, -0.07784483]),
#  'erp manager(informatique)': array([0.40324154, 0.57775486]),
#  'it info & communication coord': array([ 0.56449181, -0.5003702 ]),
#  'level designer(informatique)': array([0.75439966, 0.01359179]),
#  'chef équ supp pipeline (que)': array([-0.22910193, -0.70149618]),
#  'artistic director visual design': array([0.58449882, 0.45415193]),
#  'assistant de production(services professionnels)': array([-0.12412196, -0.84273595]),
#  'poject manager - database administrator(services professionnels)': array([ 0.38560128, -0.59222209]),
#  'brand creative director(gestion)': array([ 0.40263945, -0.66547519]),
#  'physic programmer': array([ 0.43569505, -0.41688523]),
#  'it director': array([-0.05888622,  0.76963508]),
#  'support team leader': array([-0.34472555,  0.66336441]),
#  'accounts payable manager': array([-0.83777738,  0.13813937]),
#  'spécialiste en communications': array([-0.38412029,  0.63488674]),
#  'stagiaire(services professionnels)': array([0.58384484, 0.45579898]),
#  'human resources director': array([-0.06164056, -0.20180416]),
#  'programming team lead(services professionnels)': array([-0.89288849, -0.20979729]),
#  'km services director': array([ 0.13830546, -0.84791934]),
#  'n/a(informatique)': array([ 0.773642  , -0.29495704]),
#  'gns service delivery manager': array([0.58083791, 0.13375525]),
#  'technical writer (qc)': array([0.57935345, 0.16226064]),
#  'global senior production director': array([0.60340899, 0.44306535]),
#  'storyboardist(design)': array([-0.38881928,  0.6257621 ]),
#  'coord aux opérations - ubik': array([ 0.27071121, -0.15516371]),
#  'data analyst': array([-0.05682392, -0.20272805]),
#  'coord - hot-line (monde)': array([-0.25822669, -0.05090347]),
#  'gameplay animator': array([-0.04282036, -0.20947896]),
#  'applications administrator gns': array([0.37474653, 0.1877487 ]),
#  'chef de production - helix': array([-0.88249397,  0.12730192]),
#  'coord - rémunération et sirh(services support)': array([-0.0319414 , -0.41464299]),
#  'director - working units': array([-0.41708592, -0.176368  ]),
#  'coord support technique(services support)': array([-0.9560585 ,  0.07054028]),
#  'intégrateur localisation(artistique)': array([0.14115322, 0.76778036]),
#  'voice designer': array([ 0.3494038 , -0.19200478]),
#  'product specialist - tools and automation': array([ 0.05852636, -0.7976318 ]),
#  'artiste tracking / layout': array([ 0.71771085, -0.40284359]),
#  'localization project manager(services support)': array([-0.04599686, -0.20286991]),
#  'brand artistic director': array([ 0.34340376, -0.45393392]),
#  'dt prod pipeline': array([0.48975423, 0.55801076]),
#  'interior design team lead': array([-0.22292541, -0.8037495 ]),
#  'game economy designer': array([0.4022277 , 0.53291368]),
#  'microsoft  architect': array([-0.61830878, -0.52834618]),
#  'tools tester(contrôle qualité)': array([-0.02202437, -0.17770711]),
#  'modeler(contrôle qualité)': array([0.19960691, 0.74802941]),
#  '3d animator(design)': array([0.68132651, 0.20943397]),
#  'directeur métier - qa / tools': array([0.340729 , 0.2082575]),
#  'opérateur sécurité': array([-0.86903369,  0.17521228]),
#  'responsable gestion acteurs': array([-0.76757967,  0.12723963]),
#  'operations analyst - quality assurance': array([0.43162927, 0.57694167]),
#  'responsable prod graphique': array([ 0.15236783, -0.15417062]),
#  'tools programmer(tools automation)': array([-0.41635582,  0.62898701]),
#  'bi specialist - hr': array([-0.05183427, -0.20272112]),
#  'property management director': array([-0.33783624,  0.73138565]),
#  'gns infrastructure services director': array([-0.37156656,  0.63780719]),
#  'dir. studios serv prod & it': array([-0.3154797 ,  0.72517455]),
#  'talent development team lead': array([0.55733258, 0.48473692]),
#  'coordonnateur sécurité': array([-0.03746393, -0.20051004]),
#  'it development team lead': array([-0.2588599,  0.0340902]),
#  'microsoft administrator(informatique)': array([0.54641551, 0.42612058]),
#  'user research analyst': array([ 0.27539638, -0.18489055]),
#  'cp studio web(artistique)': array([0.54345357, 0.46012083]),
#  'responsable service technique': array([-0.56192774,  0.26819909]),
#  'coord - opération & logistique(services professionnels)': array([0.58938468, 0.44908267]),
#  'taxonomist': array([ 0.22763133, -0.20739244]),
#  'technical architect(it corpo)': array([ 0.00300002, -0.71637863]),
#  'enterprise content strategy manager': array([-0.2592544 , -0.04512488]),
#  'event project manager': array([0.74551725, 0.0428169 ]),
#  'public relations project manager': array([0.74802941, 0.02225967]),
#  'compensation director': array([ 0.53768194, -0.30853501]),
#  'sound specialist and mixer': array([ 0.20285954, -0.79863524]),
#  'stagiaire(tools automation)': array([-0.30665609,  0.74112624]),
#  'directeur pipeline': array([-0.37806144,  0.62249565]),
#  'network programmer': array([ 0.2033751 , -0.47261572]),
#  'sound supervisor': array([ 0.26569733, -0.20419171]),
#  "chef d'équipe serv clientèle": array([-0.03924941, -0.20135087]),
#  'assistant executive producer(services professionnels)': array([-0.34978789,  0.72815728]),
#  'site reliability specialist': array([ 0.08870996, -0.85365295]),
#  'responsable prod audio': array([-0.71487343, -0.4941349 ]),
#  'team lead playtest': array([ 0.01655375, -0.37668425]),
#  'executive director, data platform': array([ 0.13584869, -0.8485595 ]),
#  'security awareness & comm mgr': array([ 0.75851041, -0.24293593]),
#  'animation team lead(informatique)': array([ 0.2597388 , -0.21680772]),
#  'stag informatique t1(informatique)': array([-0.34626192,  0.63570333]),
#  'gns technical account manager': array([-0.01982021, -0.19996332]),
#  'vp business strategy and live performance': array([7.65486240e-01, 5.88239345e-05]),
#  'assistant chef comptable': array([-0.4712351,  0.6755479]),
#  'management/marketing trade director': array([0.53885496, 0.5329864 ]),
#  'modeler(services professionnels)': array([ 0.16628489, -0.14330895]),
#  'live qa specialist tester': array([ 0.35263565, -0.14798719]),
#  'ww quality control director': array([-0.33492273,  0.67394584]),
#  'procurement director': array([-0.37599567, -0.70289761]),
#  'vice president, corporate affairs': array([0.59504563, 0.45291317]),
#  'production supervisor': array([ 0.01516619, -0.85546267]),
#  'internal mobility coordinator': array([0.05413186, 0.74491173]),
#  'assistant technical director - design': array([-0.8694939 ,  0.17785589]),
#  'product specialist - artistic': array([ 0.69181103, -0.46953613]),
#  'gestion communauté pipeline(gestion)': array([-0.96200317,  0.27939984]),
#  'directeur dev et recherche(informatique)': array([-0.29742765, -0.69935775]),
#  'game security manager': array([ 0.27574584, -0.62435031]),
#  ...}

# %%
# plt.figure(figsize=(14,7))
# node_size = 200
# pos = {state:list(state) for state in states}
# pos = {state:list(state) for state in [(i[0],j[0]) for i in enumerate(states) for j in enumerate(states)]}
# pos = nx.spring_layout(G)
# # pos = nx.spectral_layout(G, weight='weight',scale=0.5)
# nx.draw_networkx_edges(G, pos,width=1.0,alpha=0.5)
# nx.draw_networkx_labels(G, pos, font_weight=2)
# nx.draw_networkx_edge_labels(G, pos, edge_labels)

# plt.axis('off');

# %%
# plt.figure(figsize=(14,7))
# pos = nx.spring_layout(G)
# nx.draw(G, pos, with_labels=True, connectionstyle='arc3, rad = 0.1')
# edge_labels=dict([((u,v,),d['weight'])
#              for u,v,d in G.edges(data=True)])

# nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, label_pos=0.3, font_size=7)
# plt.show()

# %% [markdown]
# ## Calculate the shortest (ie. most probable path) between two states

# %%
state_from = '3d animator'
state_to = 'production coordinator'

# %%
nx.shortest_path(G, source=state_from, target=state_to, weight='weight', method='dijkstra')
# Out:
# ['3d animator', 'production coordinator']
